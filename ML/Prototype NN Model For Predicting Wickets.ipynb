# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Final-full.csv")

# %%
df.dtypes
# Out:
# Player Name              object
# Opposition               object
# Ground                   object
# No Of Matches             int64
# Last 5 AVG Overs          int64
# Last 5 AVG Mdns           int64
# Last 5 AVG Runs           int64
# Last 5 AVG Wkts           int64
# Last 5 AVG SR           float64
# Last 5 AVG MatchWin%    float64
# Wkts                      int64
# Day/Night                object
# Fielding Inning          object
# Tournament Type          object
# dtype: object

# %%
df
# Out:
#               Player Name Opposition         Ground  No Of Matches  \
# 0     Dushmantha Chameera    v India  Colombo (RPS)              3
# 1     Dushmantha Chameera    v India  Colombo (RPS)              3
# 2     Dushmantha Chameera    v India  Colombo (RPS)              3
# 3     Dushmantha Chameera    v India  Colombo (RPS)              3
# 4     Dushmantha Chameera    v India  Colombo (RPS)              3
# ...                   ...        ...            ...            ...
# 5440  Dushmantha Chameera    v India  Colombo (RPS)              3
# 5441  Dushmantha Chameera    v India  Colombo (RPS)              3
# 5442  Dushmantha Chameera    v India  Colombo (RPS)              3
# 5443  Dushmantha Chameera    v India  Colombo (RPS)              3
# 5444  Dushmantha Chameera    v India  Colombo (RPS)              3
#
#       Last 5 AVG Overs  Last 5 AVG Mdns  Last 5 AVG Runs  Last 5 AVG Wkts  \
# 0                    9                1               38                1
# ...

# %%
df.dtypes
# Out:
# Player Name              object
# Opposition               object
# Ground                   object
# No Of Matches             int64
# Last 5 AVG Overs          int64
# Last 5 AVG Mdns           int64
# Last 5 AVG Runs           int64
# Last 5 AVG Wkts           int64
# Last 5 AVG SR           float64
# Last 5 AVG MatchWin%    float64
# Wkts                      int64
# Day/Night                object
# Fielding Inning          object
# Tournament Type          object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
df['Player Name'] = label.fit_transform(df['Player Name'])
df['Opposition'] = label.fit_transform(df['Opposition'])
df['Ground'] = label.fit_transform(df['Ground'])
df['Day/Night'] = label.fit_transform(df['Day/Night'])
df['Fielding Inning'] = label.fit_transform(df['Fielding Inning'])
df['Tournament Type'] = label.fit_transform(df['Tournament Type'])

# %%
# categorical_data = df.drop(["Round OP AVG Wickets","Round GR AVG Wickets","Wkts","Last5MatchOvers","Last5MatchMdns","Last5MatcRuns","Last5MatchWkts","Last5MatchSR","LastMatchWin%"], axis=1)

# encoded_Player_Name = pd.get_dummies(categorical_data['Player Name'])
# encoded_Opposition = pd.get_dummies(categorical_data['Opposition'])
# encoded_Ground = pd.get_dummies(categorical_data['Ground'])
# encoded_DayNight = pd.get_dummies(categorical_data['Day/Night'])
# encoded_Fielding_Inning = pd.get_dummies(categorical_data['Fielding Inning'])
# encoded_Tournament_Type = pd.get_dummies(categorical_data['Tournament Type'])

# numerical_data = df.drop(["Player Name", "Opposition", "Ground", "Day/Night", "Fielding Inning", "Tournament Type"], axis=1)
# numerical_data.head()

# %%
# new_dataset=numerical_data.join(encoded_Player_Name)
# new_dataset=new_dataset.join(encoded_Opposition)
# new_dataset=new_dataset.join(encoded_Ground)
# new_dataset=new_dataset.join(encoded_DayNight)
# new_dataset=new_dataset.join(encoded_Fielding_Inning)
# new_dataset=new_dataset.join(encoded_Tournament_Type)
# new_dataset.head()

# %%
# new_dataset.to_csv('out.csv')

# %%
#df.to_csv('out.csv')

# %%
feature_names = ['Player Name','Opposition','Ground','Day/Night','Fielding Inning','Tournament Type','Last 5 AVG Overs','Last 5 AVG Mdns','Last 5 AVG Runs','Last 5 AVG Wkts','Last 5 AVG SR','Last 5 AVG MatchWin%']
# feature_names1 = ["Player Name", "Opposition", "Ground", "Day/Night", "Fielding Inning", "Tournament Type"]
# feature_names2 = ["Last5MatchOvers","Last5MatchMdns","Last5MatcRuns","Last5MatchWkts","Last5MatchSR","LastMatchWin%"]
X = df[feature_names]
Y = df["Wkts"]

# %%
# X = new_dataset.drop(["Wkts"], axis=1)
# Y = new_dataset["Wkts"]

# %%
data=X.values
target=Y.values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_data = MinMaxScaler()
#scaler_target = MinMaxScaler()

data_scaled=scaler_data.fit_transform(data)
#target_scaled=scaler_target.fit_transform(target)

# %%
# print('Scaled:',target.T)
# print('Scaled:',target_scaled.T)
# print('Inverse scaled:',scaler_target.inverse_transform(target_scaled).T)

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_target, test_target = train_test_split(data, target,random_state=7,test_size=0.2)

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout
import numpy as np

model = Sequential()
model.add(Dense(1024, input_dim=12, activation='sigmoid',kernel_initializer='normal'))
#model.add(Dropout(0.5))
model.add(Dense(750, activation='sigmoid'))
#model.add(Dropout(0.5))
model.add(Dense(512, activation='sigmoid'))
#model.add(Dropout(0.5))
model.add(Dense(256, activation='sigmoid'))
#model.add(Dropout(0.5))
model.add(Dense(128, activation='sigmoid'))
#model.add(Dropout(0.5))
model.add(Dense(64, activation='sigmoid'))
#model.add(Dropout(0.5))
model.add(Dense(32, activation='sigmoid'))
#model.add(Dropout(0.5))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(1, activation='relu'))

model.compile(optimizer='adam',loss='mse',metrics=['mse','mae'])

model.summary()

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout
import numpy as np

model = Sequential()
model.add(Dense(512, input_dim=12, activation='sigmoid',kernel_initializer='normal'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(1, activation='relu'))
model.compile(optimizer='adam',loss='mse',metrics=['mse','mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 512)               6656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 10)                330
#
#  dense_6 (Dense)             (None, 1)                 11
#
# ...
# Total params: 181,557
# Trainable params: 181,557
# Non-trainable params: 0
# ...

# %%
history=model.fit(train_data,train_target,epochs=1000,batch_size=100,validation_data=(test_data,test_target))
# Out:
# Epoch 1/1000
# 44/44 [==============================] - 1s 12ms/step - loss: 1.5315 - mse: 1.5315 - mae: 0.9471 - val_loss: 1.2730 - val_mse: 1.2730 - val_mae: 0.9261
# Epoch 2/1000
# 44/44 [==============================] - 0s 6ms/step - loss: 1.3285 - mse: 1.3285 - mae: 0.9224 - val_loss: 1.2771 - val_mse: 1.2771 - val_mae: 0.9315
# Epoch 3/1000
# 44/44 [==============================] - 0s 6ms/step - loss: 1.3261 - mse: 1.3261 - mae: 0.9195 - val_loss: 1.2705 - val_mse: 1.2705 - val_mae: 0.9225
# Epoch 4/1000
# 44/44 [==============================] - 0s 6ms/step - loss: 1.3317 - mse: 1.3317 - mae: 0.9199 - val_loss: 1.2741 - val_mse: 1.2741 - val_mae: 0.9277
# Epoch 5/1000
# 44/44 [==============================] - 0s 6ms/step - loss: 1.3060 - mse: 1.3060 - mae: 0.9099 - val_loss: 1.2725 - val_mse: 1.2725 - val_mae: 0.9255
# Epoch 6/1000
# ...

# %%
from matplotlib import pyplot as plt
plt.plot(model.history.history['loss'],label='loss')
plt.plot(model.history.history['val_loss'],label='val loss')
plt.legend()
plt.xlabel('#epoch')
plt.ylabel('loss')
plt.show()

# %%
predicted_target=model.predict(test_data)
# Out:
# 35/35 [==============================] - 0s 2ms/step

# %%
print('actual:',test_target[:10].T)
print('predicted:',predicted_target[:10].T)
# Out:
# actual: [0 2 1 0 0 1 1 0 2 5]
# predicted: [[0.7745052  1.1912245  0.74763805 1.1805807  0.3402902  0.20014365
#   1.2904897  0.16571186 0.8109128  1.9461864 ]]

# %%
from sklearn.metrics import r2_score
r2 = r2_score(test_target, predicted_target)
print("r2 score :",r2)
# Out:
# r2 score : 0.5961088672658592
